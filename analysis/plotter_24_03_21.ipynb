# %%
import pickle #read pickle file
import coffea
from coffea import hist
import topcoffea.modules.HistEFT as HistEFT
import topcoffea.modules.eft_helper as efth
import gzip #read zipped pickle file
import matplotlib.pyplot as plt #plot histograms
from matplotlib.backends.backend_pdf import PdfPages
import topcoffea.modules.utils as utils
import mplhep as hep

import numpy as np

import ttbarEFT.modules.plotting_tools as pt
# Out:
# /afs/crc.nd.edu/user/h/hnelson2/miniconda3/envs/ttbarEFT-env/lib/python3.9/site-packages/coffea/util.py:154: FutureWarning: In coffea version v2023.3.0 (target date: 31 Mar 2023), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %%
hep.style.use("CMS")
params = {'axes.labelsize': 20,
          'axes.titlesize': 20,
          'legend.fontsize':20}
plt.rcParams.update(params)

# %%
fin = "all_central_EFT.pkl.gz"
hists = utils.get_hist_from_pkl(fin, allow_empty=False)
print(hists)

# %%
print(hists["njets"].values())
pt.make_sm_histo(hists, "njets", "njets")

# %%
fin = "TT01j2l_v8_djr.pkl.gz"
hists = utils.get_hist_from_pkl(fin, allow_empty=False)
print(hists)
# Out:
# {'djr_10_all': <HistEFT (sample,djr_10_all) instance at 0x7f58272f0250>, 'djr_10_0p': <HistEFT (sample,djr_10_0p) instance at 0x7f58272f0cd0>, 'djr_10_1p': <HistEFT (sample,djr_10_1p) instance at 0x7f582c459070>}

# %%
pt.make_djr01_sm_plot(hists, "TT01j2l")
# Out:
# /afs/crc.nd.edu/user/h/hnelson2/miniconda3/envs/ttbarEFT-env/lib/python3.9/site-packages/coffea/hist/plot.py:333: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(0, None)
# /afs/crc.nd.edu/user/h/hnelson2/miniconda3/envs/ttbarEFT-env/lib/python3.9/site-packages/coffea/hist/plot.py:333: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(0, None)
# /afs/crc.nd.edu/user/h/hnelson2/miniconda3/envs/ttbarEFT-env/lib/python3.9/site-packages/coffea/hist/plot.py:333: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(0, None)
# figure saved to:  TT01j2l_sm_djr01.png

# %%
rwgt = {'ctGRe':2, 'ctGIm':2}
pt.make_djr01_rwgt_plot(hists, rwgt, "TT01j2l")
# Out:
# /afs/crc.nd.edu/user/h/hnelson2/miniconda3/envs/ttbarEFT-env/lib/python3.9/site-packages/coffea/hist/plot.py:333: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(0, None)
# /afs/crc.nd.edu/user/h/hnelson2/miniconda3/envs/ttbarEFT-env/lib/python3.9/site-packages/coffea/hist/plot.py:333: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(0, None)
# /afs/crc.nd.edu/user/h/hnelson2/miniconda3/envs/ttbarEFT-env/lib/python3.9/site-packages/coffea/hist/plot.py:333: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(0, None)
# figure saved to:  TT01j2l_rwgt_djr01.png
